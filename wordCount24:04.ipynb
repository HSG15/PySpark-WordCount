# %%
from pyspark.sql import SparkSession

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://my-first-cluster-m.us-central1-f.c.striking-berm-457204-i1.internal:36775">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark = SparkSession.builder.appName('Word Count App').master('yarn').getOrCreate()
# Out:
# 25/04/24 14:34:23 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
sc = spark.sparkContext

# %% [markdown]
# cd tmp
#
# vi inputhdfsdbz.txt
#
# hadoop fs -put inputhdfsdbz.txt /tmp/          : Now we can see it in HDFS NameNode

# %%
hdfs_path = '/tmp/inputdbztest.txt'

# %%
rdd = sc.textFile(hdfs_path)

# %%
rdd.collect()
# Out:
# ['dear bear car', 'car car bear', 'dear dear bear']

# %%
flatMappedData = rdd.flatMap(lambda word : word.split())

# %%
flatMappedData.collect()
# Out:
# ['dear', 'bear', 'car', 'car', 'car', 'bear', 'dear', 'dear', 'bear']

# %%
mappedData = flatMappedData.map(lambda x : (x, 1))

# %%
mappedData.collect()
# Out:
# [('dear', 1),
#  ('bear', 1),
#  ('car', 1),
#  ('car', 1),
#  ('car', 1),
#  ('bear', 1),
#  ('dear', 1),
#  ('dear', 1),
#  ('bear', 1)]

# %%
reducedData = mappedData.reduceByKey(lambda a,b : a+b)

# %%
reducedData.collect()
# Out:
# [('bear', 3), ('car', 3), ('dear', 3)]
